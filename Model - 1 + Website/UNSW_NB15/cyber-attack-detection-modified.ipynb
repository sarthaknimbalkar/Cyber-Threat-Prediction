# %% [markdown]
# ## Overview of Cyber Attack Types
#
# The dataset encompasses nine distinct categories of cyber attacks, each characterized by its specific methodology and objective:
#
# 1. **Fuzzers**: These attacks involve sending random data to a system with the intention of testing its resilience and identifying potential vulnerabilities.
#
# 2. **Analysis**: This type of attack entails scrutinizing a system to uncover its weaknesses and pinpoint potential targets for exploitation.
#
# 3. **Backdoors**: Attackers create hidden entry points within a system, which can be utilized at a later stage to gain unauthorized access.
#
# 4. **DoS (Denial of Service)**: These attacks aim to disrupt the normal functioning of a system, rendering it unavailable to legitimate users.
#
# 5. **Exploits**: Leveraging vulnerabilities in a system, these attacks seek to gain unauthorized access or control over the target.
#
# 6. **Generic**: Serving as a catch-all category, it encompasses various attack types that do not fit neatly into the other predefined categories.
#
# 7. **Reconnaissance**: Attackers gather information about a target system, including vulnerabilities and potential entry points, in preparation for subsequent attacks.
#
# 8. **Shellcode**: Malicious code, typically in the form of shell scripts, is executed on a target system to carry out nefarious activities.
#
# 9. **Worms**: This type of malware automatically spreads to other systems, often causing significant harm in the process.
#
# By understanding these distinct categories of cyber attacks, individuals and organizations can better prepare themselves to mitigate potential security threats and safeguard their systems and data.

# %%
Fuzzers = [
    'Input Validation',
    'Bounds Checking',
    'Error Handling',
    'Patch Management',
    'Intrusion Detection and Prevention Systems'
    ]

Analysis=[
    'Vulnerability Assesments',
    'Penetration Testing',
    'Patch Management',
    'Netwrok segmentaion',
    'Intrusion Detection and Prevention Systems (IDPS)'
    ]
Backdoors=[
    'Access Control and Privilege Management',
    'Network Monitoring',
    'Secure Software Development Lifecycle ',
    "Encryption and Secure Communication",
    'Incident Response and Recovery'
    ]
Dos=['Use services that help filter out malicious traffic and  ensuring that legitimate requests',
     'Traffic Rate Limiting',
     'Distribute incoming traffic across multiple servers',
     'Intrusion Detection and Prevention Systems (IDPS)',
     'Implement access control lists (ACLs) or firewalls to block known malicious IP addresses or suspicious traffic patterns',
     'Anomaly Detection']

Exploits =[
    'Vulnerability Management',
    ' Penetration Testing',
    'Web Application Firewalls (WAF)',
    'Privilege Separation',
    'Intrusion Detection and Prevention Systems (IDPS)',
    'Implement access control lists (ACLs) or firewalls to block known malicious IP addresses or suspicious traffic patterns',
    'Security Patch Management',

]


Generic =[
    'Use services that help filter out malicious traffic and  ensuring that legitimate requests',
    'Traffic Rate Limiting',
    'Distribute incoming traffic across multiple servers',
    'Intrusion Detection and Prevention Systems (IDPS)',
    'Implement access control lists (ACLs) or firewalls to block known malicious IP addresses or suspicious traffic patterns',
    'Anomaly Detection',
    'Security Patch Management',
    'Web Application Firewalls (WAF)',
    'Privilege Separation',
    'Intrusion Detection and Prevention Systems (IDPS)',
    'Implement access control lists (ACLs) or firewalls to block known malicious IP addresses or suspicious traffic patterns',
    'Security Patch Management',
    'Web Application Firewalls (WAF)',
    'Privilege Separation',
    'Intrusion Detection and Prevention Systems (IDPS)',
]

Reconnaissance=[
    'Threat Intelligence Monitoring',
    'Web Application Firewalls (WAF)',
    'Network Segmentation',

    'Intrusion Detection and Prevention Systems (IDPS)',
    'Log Monitoring and Analysis',
    'Web Scraping Protection',
    'Regular Vulnerability Assessments'

]

Shellcode=[
    'Application Whitelisting', 
    'Sandboxing',
    'Network Segmentation',
    'Regular Patching and Updates',
    'monitoring system calls and  API usage and memory access patterns',
    'Intrusion Detection and Prevention Systems (IDPS)',
    

    ]

Worms=[
    'Network Segmentation',
    'Patch Management',
    'Intrusion Detection and Prevention Systems (IDPS)',
    'Antivirus and Anti-Malware Solutions',
    'Regular Backups',
    'Incident Response Planning'
]

mitigations={
    'Fuzzers':Fuzzers,
    'Analysis':Analysis,
    'Backdoors':Backdoors,
    'Dos':Dos,
    'Exploits':Exploits,
    'Generic':Generic,
    'Reconnaissance':Reconnaissance,
    'Shellcode':Shellcode,
    'Worms':Worms
   
}

# %% [markdown]
# ## Installing Libraries

# %%
# %pip install nbformat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install graphviz
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %pip install dtreeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dtreeviz

# Ignore warnings
warnings.filterwarnings('ignore')

# Set up visualization styles
sns.set_context('notebook')
sns.set_style('white')

# %% [markdown]
# ## Data Preparation

# %%
# Read training and testing datasets
# training = pd.read_csv("train_dataset.csv")
# testing = pd.read_csv("test_dataset.csv")
# validation = pd.read_csv("validation_dataset.csv")
df=pd.read_csv('combined_dataset.csv')
# print(f"Validation data shape: {validation.shape}")

# print(f"Training data shape: {training.shape}")
# print(f"Testing data shape: {testing.shape}")

# %%
all(training.columns == testing.columns)
# Out:
# True

# %%
# Concatenate training and testing datasets, drop 'id' column, and reset index
# df = pd.concat([training, testing]).drop('id', axis=1).reset_index(drop=True)
df=df.drop('id', axis=1).reset_index(drop=True)

# Display the first few rows of the concatenated DataFrame
df.head()
# Out:
#         dur proto service state  spkts  dpkts  sbytes  dbytes       rate  \
# 0  0.121478   tcp       -   FIN      6      4     258     172  74.087490
# 1  0.649902   tcp       -   FIN     14     38     734   42014  78.473372
# 2  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# 4  0.449454   tcp       -   FIN     10      6     534     268  33.373826
#
#    sttl  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0   252  ...                 1               1             0           0
# 1    62  ...                 1               2             0           0
# 2    62  ...                 1               3             0           0
# 3    62  ...                 1               3             1           1
# 4   254  ...                 1              40             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# ...

# %%
df['ct_state_ttl'].unique()
# Out:
# array([0, 1, 2, 3, 6, 4, 5], dtype=int64)

# %%
df.columns
# Out:
# Index(['dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257673 entries, 0 to 257672
# Data columns (total 44 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dur                257673 non-null  float64
#  1   proto              257673 non-null  object
#  2   service            257673 non-null  object
#  3   state              257673 non-null  object
#  4   spkts              257673 non-null  int64
#  5   dpkts              257673 non-null  int64
#  6   sbytes             257673 non-null  int64
#  7   dbytes             257673 non-null  int64
#  8   rate               257673 non-null  float64
#  9   sttl               257673 non-null  int64
#  10  dttl               257673 non-null  int64
#  11  sload              257673 non-null  float64
#  12  dload              257673 non-null  float64
#  13  sloss              257673 non-null  int64
#  14  dloss              257673 non-null  int64
# ...

# %%
df.attack_cat.unique()
# Out:
# array(['Normal', 'Backdoor', 'Analysis', 'Fuzzers', 'Shellcode',
#        'Reconnaissance', 'Exploits', 'DoS', 'Worms', 'Generic'],
#       dtype=object)

# %%
severity_duration_mapping = {
    'Normal': {'severity': 'Low', 'duration': 'Short'},
    'Backdoors': {'severity': 'High', 'duration': 'Long'},
    'Analysis': {'severity': 'Medium', 'duration': 'Medium'},
    'Fuzzers': {'severity': 'High', 'duration': 'Medium'},
    'Shellcode': {'severity': 'High', 'duration': 'Medium'},
    'Reconnaissance': {'severity': 'Low', 'duration': 'Short'},
    'Exploits': {'severity': 'High', 'duration': 'Medium'},
    'DoS': {'severity': 'High', 'duration': 'Long'},
    'Worms': {'severity': 'High', 'duration': 'Long'},
    'Generic': {'severity': 'Medium', 'duration': 'Medium'}
}

# Function to map attack categories to severity
def get_severity(attack_cat):
    return severity_duration_mapping.get(attack_cat, {}).get('severity', 'Unknown')

# Function to map attack categories to duration
def get_duration(attack_cat):
    return severity_duration_mapping.get(attack_cat, {}).get('duration', 'Unknown')

# Create new columns for severity and duration
df['severity'] = df['attack_cat'].apply(get_severity)
df['duration'] = df['attack_cat'].apply(get_duration)

print(df['severity'].unique())
# Out:
# ['Low' 'Unknown' 'Medium' 'High']

# %%
df.to_csv('new_combined.csv', index=False)

# %% [markdown]
# ## Categorical data

# %%
# Convert categorical columns to numerical codes
# cat_cols = ['proto', 'service', 'state']
# # new=[10.0, 'TCP', 'http', 'ESTABLISHED', 20, 15, 2000, 1500, 1000, 64, 128, 800, 600, 5, 3, 50, 40, 10, 8, 500, 1000, 2000, 1500, 1000, 50, 30, 20, 15, 0, 0, 1, 200, 5, 2, 3, 2, 10, 3, 5, 0]
# new=[10.0, 113, 0, 4, 20, 15, 2000, 1500, 1000, 64, 128, 800, 600, 5, 3, 50, 40, 10, 8, 500, 1000, 2000, 1500, 1000, 50, 30, 20, 15, 0, 0, 1, 200, 5, 2, 3, 2, 10, 3, 5, 0]
# df[cat_cols] = df[cat_cols].apply(lambda x: x.astype('category').cat.codes)
cat_cols = ['proto', 'service', 'state']
# mapping_dicts = {}  # Dictionary to store mappings for each categorical column
mapping_dicts = {}  # Dictionary to store mapping dictionaries for each column

# Iterate over each column in cat_cols
for col in cat_cols:
    # Get unique values of the column
    unique_values = df[col].unique().tolist()
    mapping_dicts[col] ={}
    for i in unique_values:
        mapping_dicts[col][i] = unique_values.index(i) + 1

    
   


mapping_dicts
# Out:
# {'proto': {'tcp': 1,
#   'udp': 2,
#   'arp': 3,
#   'ospf': 4,
#   'icmp': 5,
#   'igmp': 6,
#   'rtp': 7,
#   'ddp': 8,
#   'ipv6-frag': 9,
#   'cftp': 10,
#   'wsn': 11,
#   'pvp': 12,
#   'wb-expak': 13,
#   'mtp': 14,
#   'pri-enc': 15,
#   'sat-mon': 16,
#   'cphb': 17,
#   'sun-nd': 18,
#   'iso-ip': 19,
#   'xtp': 20,
#   'il': 21,
#   'unas': 22,
#   'mfe-nsp': 23,
#   '3pc': 24,
#   'ipv6-route': 25,
#   'idrp': 26,
#   'bna': 27,
#   'swipe': 28,
#   'kryptolan': 29,
#   'cpnx': 30,
#   'rsvp': 31,
#   'wb-mon': 32,
#   'vmtp': 33,
#   'ib': 34,
#   'dgp': 35,
#   'eigrp': 36,
#   'ax.25': 37,
#   'gmtp': 38,
#   'pnni': 39,
#   'sep': 40,
#   'pgm': 41,
#   'idpr-cmtp': 42,
#   'zero': 43,
#   'rvd': 44,
#   'mobile': 45,
#   'narp': 46,
#   'fc': 47,
#   'pipe': 48,
#   'ipcomp': 49,
#   'ipv6-no': 50,
#   'sat-expak': 51,
#   'ipv6-opts': 52,
#   'snp': 53,
#   'ipcv': 54,
#   'br-sat-mon': 55,
#   'ttp': 56,
#   'tcf': 57,
#   'nsfnet-igp': 58,
#   'sprite-rpc': 59,
# ...

# %% [markdown]
# mapping_dicts

# %%
mapping_dicts

# %%
df.head()
# Out:
#         dur  proto  service  state  spkts  dpkts  sbytes  dbytes       rate  \
# 0  0.121478    113        0      4      6      4     258     172  74.087490
# 1  0.649902    113        0      4     14     38     734   42014  78.473372
# 2  1.623129    113        0      4      8     16     364   13186  14.170161
# 3  1.681642    113        3      4     12     12     628     770  13.677108
# 4  0.449454    113        0      4     10      6     534     268  33.373826
#
#    sttl  ...  is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  \
# 0   252  ...             0           0                 0           1
# 1    62  ...             0           0                 0           1
# 2    62  ...             0           0                 0           2
# 3    62  ...             1           1                 0           2
# 4   254  ...             0           0                 0           2
#
#    ct_srv_dst  is_sm_ips_ports  attack_cat  label  severity  duration
# ...

# %%
df['state'].unique()
# Out:
# array([ 4,  5,  2,  3,  7,  8,  6,  9, 10,  0,  1], dtype=int8)

# %%
df['sttl'].unique()
# Out:
# array([252,  62, 254,   0,   1,  31,  63,  64,  60,  29, 255,  32,  30],
#       dtype=int64)

# %%
unique_values = df['sttl'].unique()

# Sort unique values and enumerate them to create a mapping dictionary
sttl_dict = {val: idx for idx, val in enumerate(np.sort(unique_values))}
sttl_dict
# Out:
# {0: 0,
#  1: 1,
#  29: 2,
#  30: 3,
#  31: 4,
#  32: 5,
#  60: 6,
#  62: 7,
#  63: 8,
#  64: 9,
#  252: 10,
#  254: 11,
#  255: 12}

# %%
sttl_dict

# %%
df['ct_state_ttl'].unique()
# Out:
# array([0, 1, 2, 3, 6, 4, 5], dtype=int64)

# %%
df['ct_state_ttl'].unique()
unique_values = df['ct_state_ttl'].unique()

# Sort unique values and enumerate them to create a mapping dictionary
ct_state_ttl = {val: idx for idx, val in enumerate(np.sort(unique_values))}
ct_state_ttl
# Out:
# {0: 0,
#  1: 1,
#  29: 2,
#  30: 3,
#  31: 4,
#  32: 5,
#  60: 6,
#  62: 7,
#  63: 8,
#  64: 9,
#  252: 10,
#  254: 11,
#  255: 12}

# %%
ct_state_ttl

# %%
df['rate'].unique()
# Out:
# array([74.08749 , 78.473372, 14.170161, ..., 18.474862, 25.351192,
#        24.410067])

# %%
df['dload'].unique()
# Out:
# array([  8495.365234, 503571.3125  ,  60929.23047 , ...,   2207.130127,
#          1546.616211,   2242.109863])

# %%
df['sbytes'].unique()
# Out:
# array([   258,    734,    364, ..., 128392,   3376, 138067], dtype=int64)

# %%
df['ct_srv_dst'].unique()
# Out:
# array([ 1,  6, 39,  3,  2,  8,  5, 11,  9,  7, 62, 10,  4, 12, 21, 17, 16,
#        13, 18, 14, 19, 15, 24, 20, 26, 23, 37, 46, 28, 36, 34, 22, 29, 30,
#        40, 25, 31, 38, 35, 51, 33, 27, 44, 42, 45, 32, 41, 43, 47, 49, 50,
#        52, 59, 48, 54, 53, 58], dtype=int64)

# %%
df['smean'].unique()
# Out:
# array([  43,   52,   46, ..., 1415, 1397, 1402], dtype=int64)

# %%
df['tcprtt'].unique()
# Out:
# array([0.      , 0.111897, 0.128381, ..., 0.237125, 0.140691, 0.173208])

# %% [markdown]
# ## Visualizing attacks categories

# %%
# Calculate the counts of attack categories where label is 1 (indicating an attack)
# valid_attacks = df[df['label'] == 1]['attack_cat'].value_counts()
# df['attack_cat'].unique()
# for i in df['attack_cat'].unique().tolist():
 # Assuming 'df' is your DataFrame and 'attack_cat' is the column containing attack categories
unique_categories = df['attack_cat'].unique().tolist()

# Create a dictionary to map unique categories to numerical values
category_mapping = {cat: i for i, cat in enumerate(unique_categories)}
print(category_mapping)
# Map the numerical values to the 'attack_cat' column in the DataFrame
# print(df['attack_cat'].map(category_mapping).unique())
df['attack_cat']=df['attack_cat'].map(category_mapping)

   
    
# print(valid_attacks)
# # Plot a pie chart of attack category distribution
# plt.figure(figsize=(16, 8))
# plt.pie(valid_attacks, labels=valid_attacks.index, autopct='%1.1f%%', explode=[0] * len(valid_attacks))
# plt.title('Distribution of Attack Categories')
# plt.show()
# Out:
# {'Normal': 0, 'Backdoor': 1, 'Analysis': 2, 'Fuzzers': 3, 'Shellcode': 4, 'Reconnaissance': 5, 'Exploits': 6, 'DoS': 7, 'Worms': 8, 'Generic': 9}

# %%
category_mapping = {cat: i for i, cat in enumerate(unique_categories)}
{'Normal': 0, 'Backdoor': 1, 'Analysis': 2, 'Fuzzers': 3, 'Shellcode': 4, 'Reconnaissance': 5, 'Exploits': 6, 'DoS': 7, 'Worms': 8, 'Generic': 9}

# %% [markdown]
# * Generic and Exploits attacks are the most.

# %%
df.columns
# Out:
# Index(['dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label', 'severity',
#        'duration'],
#       dtype='object')

# %% [markdown]
# ## Splitting data

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into features (X) and target (y)
X = df.drop(columns=['attack_cat', 'label'])
y = df['attack_cat']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11)

# X_val = validation.drop(columns=['attack_cat', 'label'])
# y_val = validation['label']
# Print the shapes of training and testing sets
# print("Shape of X_train:", X_train.shape)
# print("Shape of y_train:", y_train.shape)
# print("Shape of X_test:", X_test.shape)
# print("Shape of y_test:", y_test.shape)

X.columns.size
# Out:
# 42

# %% [markdown]
# ## Decision Tree Model for Cyber Attack Detection
# In this section, we employ a decision tree model to establish criteria for detecting cyber attacks. We conduct a grid search and Randomized Search to optimize the model parameters, focusing on maximizing the recall rate. A high recall rate is crucial for creating the initial layer of protection against cyber threats.

# %% [markdown]
# ## Using RandomizedSearch

# %%
from sklearn.model_selection import RandomizedSearchCV

from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier

# Define the parameter distributions for randomized search
param_dist = {
    'criterion': ['gini', 'entropy'],
    'max_depth': randint(2, 20),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10)
}

# Initialize DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier()

# Perform randomized search
random_search = RandomizedSearchCV(dt_classifier, param_distributions=param_dist, n_iter=100, cv=5, scoring='recall', random_state=11)
random_search.fit(X_train, y_train)

# Print the best parameters and best recall score
print("Best Parameters:", random_search.best_params_)
print("Best Recall Score:", random_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 19
#      17 # Perform randomized search
#      18 random_search = RandomizedSearchCV(dt_classifier, param_distributions=param_dist, n_iter=100, cv=5, scoring='recall', random_state=11)
# ---> 19 random_search.fit(X_train, y_train)
#      21 # Print the best parameters and best recall score
#      22 print("Best Parameters:", random_search.best_params_)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
# ...

# %%
from sklearn.metrics import recall_score, accuracy_score

# Instantiate the best estimator found by grid search
clf = random_search.best_estimator_

# Fit the model to the training data
clf.fit(X_train, y_train)

# Predict labels for the test data
y_pred = clf.predict(X_test)

# Calculate recall and accuracy scores
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# Print the scores
print("Recall:", recall)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 from sklearn.metrics import recall_score, accuracy_score
#       3 # Instantiate the best estimator found by grid search
# ----> 4 clf = random_search.best_estimator_
#       6 # Fit the model to the training data
#       7 clf.fit(X_train, y_train)
#
# NameError: name 'random_search' is not defined

# %% [markdown]
# ## Visualizing the rules

# %%
from sklearn.tree import export_text
from sklearn import tree
import dtreeviz
import matplotlib.pyplot as plt

# Define feature_names (assuming it's defined earlier in your code)
feature_names = list(X_train.columns)

# Print the rules for the decision tree
print(":::::::> The RULES FOR HIGH RECALL RATE <::::::: \n")
print(export_text(clf, feature_names=feature_names))

# Visualize the decision tree using dtreeviz
viz_model = dtreeviz.model(clf,
                                                   X_train.values,
                                                   y_train.values,
                                                   target_name='class',
                                                   feature_names=feature_names,
                                                   class_names=['Normal', 'Attack'])

# viz_model.save("decision_tree.png")
viz_model.view()
# Out:
# :::::::> The RULES FOR HIGH RECALL RATE <:::::::
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 11
#       9 # Print the rules for the decision tree
#      10 print(":::::::> The RULES FOR HIGH RECALL RATE <::::::: \n")
# ---> 11 print(export_text(clf, feature_names=feature_names))
#      13 # Visualize the decision tree using dtreeviz
#      14 viz_model = dtreeviz.model(clf,
#      15                                                    X_train.values,
#      16                                                    y_train.values,
#      17                                                    target_name='class',
#      18                                                    feature_names=feature_names,
#      19                                                    class_names=['Normal', 'Attack'])
#
# NameError: name 'clf' is not defined

# %% [markdown]
# * From the decision tree, we visualized the rule of tree as sttl<=61 and sttl>61

# %% [markdown]
# ## Filtering data for potential attacks

# %%
# Reset index of X_test
X_test.reset_index(drop=True, inplace=True)

# Define the condition for filtering
condition = (X_test['sttl'] <= 61.00) & (X_test['sinpkt'] <= 0.00) | (X_test['sttl'] > 61.00)

# Filter X_test based on the condition
X_test_2 = X_test[condition]

# Reset index of y_test
y_test.reset_index(drop=True, inplace=True)

# Filter y_test based on the indices of filtered X_test
y_test_2 = y_test[X_test_2.index]

# Print the shapes and percentage of filtered data
print("Original X_test shape:", X_test.shape)
print("Filtered X_test shape:", X_test_2.shape)
filtered_percentage = (1 - X_test_2.shape[0] / X_test.shape[0]) * 100
print("Filtered data percentage:", filtered_percentage, "%")
# Out:
# Original X_test shape: (77302, 42)
# Filtered X_test shape: (59265, 42)
# Filtered data percentage: 23.3331608496546 %

# %% [markdown]
# * The rule based system filtered 23% of network traffic for further analysis, demonstrating its efficiency in detecting non-threatening network activity. Now, we will detect cyber attacks by applying the trained model to the filtered test data.

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
from sklearn.metrics import precision_score, classification_report
import seaborn as sns

def model_evaluation(model, X_test, y_test):
    # Fit the model to the training data
    model.fit(X_train, y_train)
    
    # Predict labels for the test data
    y_pred = model.predict(X_test)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    
    # Print evaluation metrics
    print("Accuracy:", accuracy)
    print("Recall:", recall)
    print("Precision:", precision)
    
    # Generate classification report
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    
    # Plot confusion matrix
    plt.figure(figsize=(5, 5))
    sns.heatmap(pd.crosstab(y_test, y_pred), annot=True, fmt='d', cmap="YlGnBu")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    
    # Return evaluation metrics
    return {'Accuracy': accuracy, 'Recall': recall, 'Precision': precision}

# %%
results = {}

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
# # Instantiate the RandomForestClassifier
# rf = RandomForestClassifier(random_state=11)

# # Evaluate the RandomForestClassifier using the model_evaluation function
# rf_results = model_evaluation(rf, X_test_2, y_test_2)

from sklearn.model_selection import StratifiedKFold, cross_val_score

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [300],
    'max_depth': [ 30],
    'min_samples_split': [ 5],
    'min_samples_leaf': [4]
}
rf = RandomForestClassifier(random_state=11)
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=11)

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=cv_strategy, scoring='accuracy')

grid_search.fit(X_train, y_train)

# Evaluate the model
# rf_results = model_evaluation(grid_search, X_test, y_test)

print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# print(rf_results)
# Out:
# Best Parameters: {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Best Score: 0.8242234104832097

# %%
# from xgboost import XGBClassifier
# from sklearn.model_selection import GridSearchCV


# param_grid = {
#     'learning_rate': [ 0.1],
#     'max_depth': [ 7],
#     'min_child_weight': [3],
#     'gamma': [ 0.2],
#     'subsample': [0.8],
#     'colsample_bytree': [0.6],
#     'reg_alpha': [ 0.1],
#     'reg_lambda': [ 0.1]
# }

# # Instantiate the XGBClassifier
# xgbc = XGBClassifier()

# # Instantiate GridSearchCV with the defined parameter grid
# grid_search = GridSearchCV(estimator=xgbc, param_grid=param_grid, cv=2, scoring='accuracy')

# # Fit the GridSearchCV to the training data
# grid_search.fit(X_train, y_train)

from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# Define your parameter grid
param_grid = {
    'learning_rate': [0.05],
    'max_depth': [10],
    'min_child_weight': [5],
    'gamma': [0.2],
    'subsample': [0.8],
    'colsample_bytree': [0.6],
    'reg_alpha': [0.1],
    'reg_lambda': [0.1]
}

# Instantiate the XGBClassifier
xgbc = XGBClassifier()

# Instantiate GridSearchCV with the defined parameter grid
grid_search = GridSearchCV(estimator=xgbc, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV to the training data
grid_search.fit(X_train, y_train)

# Print the best accuracy score and the corresponding parameters
print("Best accuracy:", grid_search.best_score_)
print("Best parameters:", grid_search.best_params_)

# model_evaluation(grid_search,X_test,y_test)
# Print the best parameters and best score
# print("Best Parameters:", grid_search.best_params_)

# print("Best Score:", grid_search.best_score_)
# Out:
# Best accuracy: 0.8299837688687276
# Best parameters: {'colsample_bytree': 0.6, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}

# %%
import joblib

# Assuming 'model' is your trained ML model
joblib.dump(grid_search, 'new_model_filename.pkl')
# Out:
# ['new_model_filename.pkl']

# %%
from sklearn.metrics import accuracy_score
import joblib

# Load the saved model
model = joblib.load('model_filename.pkl')

# Load test data
 # Implement this function to load your test data

# Make predictions
y_pred = model.predict(X_test)

# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3458384000413961

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
# # Instantiate the RandomForestClassifier
# rf = RandomForestClassifier(random_state=11)

# # Evaluate the RandomForestClassifier using the model_evaluation function
# rf_results = model_evaluation(rf, X_test_2, y_test_2)

from sklearn.model_selection import StratifiedKFold, cross_val_score

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [300],
    'max_depth': [ 30],
    'min_samples_split': [ 5],
    'min_samples_leaf': [4]
}
rf = RandomForestClassifier(random_state=11)
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=11)

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=cv_strategy, scoring='accuracy')

# grid_search.fit(X_train, y_train)

# Evaluate the model
rf_results = model_evaluation(grid_search, X_test, y_test)
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
print(rf_results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 26
#      21 grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=cv_strategy, scoring='accuracy')
#      23 # grid_search.fit(X_train, y_train)
#      24
#      25 # Evaluate the model
# ---> 26 rf_results = model_evaluation(grid_search, X_test, y_test)
#      27 print("Best Parameters:", grid_search.best_params_)
#      28 print("Best Score:", grid_search.best_score_)
#
# Cell In[8], line 6, in model_evaluation(model, X_test, y_test)
#       4 def model_evaluation(model, X_test, y_test):
#       5     # Fit the model to the training data
# ----> 6     model.fit(X_train, y_train)
#       8     # Predict labels for the test data
#       9     y_pred = model.predict(X_test)
#
# ...

# %% [markdown]
# ## Visualizing the rules present in the tree

# %%
from sklearn.tree import export_text

# Check if the Random Forest model has at least 100 estimators
if len(rf.estimators_) >= 100:
    # Get the feature names
    feature_names = list(X.columns)

    # Print the text representation of the decision tree of the 100th estimator
    print(export_text(rf.estimators_[99], feature_names=feature_names))
else:
    print("The Random Forest model does not have at least 100 estimators.")
# Out:
# |--- dpkts <= 0.50
# |   |--- ct_srv_src <= 2.50
# |   |   |--- sbytes <= 53.00
# |   |   |   |--- sinpkt <= 30000.02
# |   |   |   |   |--- sbytes <= 26.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sbytes >  26.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- sinpkt >  30000.02
# |   |   |   |   |--- class: 0.0
# |   |   |--- sbytes >  53.00
# |   |   |   |--- rate <= 0.11
# |   |   |   |   |--- sbytes <= 62.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sbytes >  62.50
# |   |   |   |   |   |--- sttl <= 143.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- sttl >  143.00
# |   |   |   |   |   |   |--- ct_src_dport_ltm <= 1.50
# |   |   |   |   |   |   |   |--- sinpkt <= 5037.05
# |   |   |   |   |   |   |   |   |--- ct_srv_dst <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- ct_srv_dst >  1.50
# |   |   |   |   |   |   |   |   |   |--- sbytes <= 803.00
# ...

# %%
from xgboost import XGBClassifier

# Instantiate the XGBClassifier
xgbc = XGBClassifier()

# Evaluate the XGBClassifier using the model_evaluation function
xgbc_results = model_evaluation(xgbc, X_test_2, y_test_2)

# Store the evaluation results in the dictionary
results['XGBoost Classifier'] = xgbc_results
# Out:
# Accuracy: 0.931729070256626
# Recall: 0.9517458777885548
# Precision: 0.9657774405872583
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80      9937
#            1       0.97      0.95      0.96     49488
#
#     accuracy                           0.93     59425
#    macro avg       0.87      0.89      0.88     59425
# weighted avg       0.93      0.93      0.93     59425

# %% [markdown]
# ## Save Trained Model

# %%
import joblib

# Assuming 'model' is your trained model object
# Train your model here...

# Save the trained model to a file
joblib.dump(model, 'trained_model.pkl')

# %%
input_data = [10.0, 'TCP', 'http', 'ESTABLISHED', 20, 15, 2000, 1500, 1000, 64, 128, 800, 600, 5, 3, 50, 40, 10, 8, 500, 1000, 2000, 1500, 1000, 50, 30, 20, 15, 0, 0, 1, 200, 5, 2, 3, 2, 10, 3, 5, 0,0,0]
print(len(input_data))
# Out:
# 42

# %%
new=[15.0, 0, 5 , , 25, 20, 3000, 2000, 1500, 64, 128, 1200, 800, 10, 5, 80, 60, 20, 15, 800, 1500, 3000, 2000, 1500, 70, 40, 30, 20, 0, 0, 1, 300, 6, 3, 3, 2, 15, 4, 6, 0,0,0],[15.0, 'TCP', 'ftp', 'CLOSE_WAIT', 25, 20, 3000, 2000, 1500, 64, 128, 1200, 800, 10, 5, 80, 60, 20, 15, 800, 1500, 3000, 2000, 1500, 70, 40, 30, 20, 0, 0, 1, 300, 6, 3, 3, 2, 15, 4, 6, 0]
len(new[0])
# Out:
# 40

# %% [markdown]
# ## PREDICTIONS

# %%
import joblib  # or pickle if you used that to save the model
import numpy as np  # if needed for data manipulation

model = joblib.load('new_model_filename.pkl')  # Replace 'trained_model.pkl' with the path to your saved model file

def preprocess_data(data):
   
    return data

# Define a function to make predictions
def make_predictions(input_data):
  
    predictions = model.predict(input_data)
    
    return predictions


input_data=pd.read_csv('new.csv')

severity=0.127* 10 + 0.098745* 6 + 4* 0.056321 + 8*0.049838 + 6*0.045 +4*0.043+ 0.040537*2 
predictions = make_predictions(input_data)
print(predictions,severity)
# Out:
# [6 6] 3.009532

# %%
def mitigation(predictions):
    for key in mitigations.keys():
        if key==predictions:
            print("Mitigatioons:",mitigations[key])
            return mitigations[key]
mitigation('Worms')
# Out:
# Mitigatioons: ['Network Segmentation', 'Patch Management', 'Intrusion Detection and Prevention Systems (IDPS)', 'Antivirus and Anti-Malware Solutions', 'Regular Backups', 'Incident Response Planning']
# ['Network Segmentation',
#  'Patch Management',
#  'Intrusion Detection and Prevention Systems (IDPS)',
#  'Antivirus and Anti-Malware Solutions',
#  'Regular Backups',
#  'Incident Response Planning']

# %%
viz_model = dtreeviz.model(xgbc,tree_index=1,
                           X_train=X_train, y_train=y_train, 
                           feature_names=feature_names)  
viz_model.view()

# %%
from lightgbm import LGBMClassifier

# Instantiate the LGBMClassifier
lgbc = LGBMClassifier()

# Evaluate the LGBMClassifier using the model_evaluation function
lgbc_results = model_evaluation(lgbc, X_test_2, y_test_2)

# Store the evaluation results in the dictionary
results['Light GBM Classifier'] = lgbc_results
# Out:
# [LightGBM] [Info] Number of positive: 115185, number of negative: 65186
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004843 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6184
# [LightGBM] [Info] Number of data points in the train set: 180371, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.638600 -> initscore=0.569295
# [LightGBM] [Info] Start training from score 0.569295
# Accuracy: 0.9267816575515355
# Recall: 0.9465122858066602
# Precision: 0.964898547739211
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79      9937
#            1       0.96      0.95      0.96     49488
#
#     accuracy                           0.93     59425
#    macro avg       0.86      0.89      0.87     59425
# ...

# %%
import lightgbm as lgb

# Fit the LGBMClassifier
lgbc.fit(X_train, y_train)

# Save the LGBMClassifier model
lgbc.booster_.save_model('lgb_model.txt')

# Load the model using LightGBM's Booster class
booster = lgb.Booster(model_file='lgb_model.txt')

# Plot the tree
lgb.plot_tree(booster, figsize=(20, 12))
plt.show()
# Out:
# [LightGBM] [Info] Number of positive: 115185, number of negative: 65186
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004780 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6184
# [LightGBM] [Info] Number of data points in the train set: 180371, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.638600 -> initscore=0.569295
# [LightGBM] [Info] Start training from score 0.569295

# %%
comparision = pd.DataFrame(results)
comparision
# Out:
#            Random Forest Model  XGBoost Classifier  Light GBM Classifier
# Accuracy              0.935196            0.931729              0.926782
# Recall                0.957182            0.951746              0.946512
# Precision             0.964726            0.965777              0.964899

# %% [markdown]
# ## Hypothesis testing:
# #### Wilcoxon rank sum test:
# * The Wilcoxon rank sum test is a non-parametric test, which means that it does not assume that the data is normally distributed. The Wilcoxon rank sum test will calculate a Z-statistic and a p-value. The Z-statistic is a measure of how much variation there is between the three recall scores. The p-value is a measure of the probability of getting a result as extreme as the one observed, if the null hypothesis is true. The null hypothesis is the hypothesis that there is no difference in the recall of the three models. If the p-value is less than 0.05, then we can reject the null hypothesis and conclude that there is a statistically significant difference in the recall of the three models.

# %%
from scipy.stats import wilcoxon

# Extract recall scores for each model
recall_model1 = comparision.iloc[0]
recall_model2 = comparision.iloc[1]
recall_model3 = comparision.iloc[2]

# Perform Wilcoxon signed-rank test
z_statistic, p_value = wilcoxon(recall_model1, recall_model2)

# Print the results
print('Z-statistic:', z_statistic)
print('p-value:', p_value)

# Interpret the results
if p_value < 0.05:
    print('The difference in the recall of the two models is statistically significant.')
else:
    print('The difference in the recall of the two models is not statistically significant.')
# Out:
# Z-statistic: 0.0
# p-value: 0.25
# The difference in the recall of the two models is not statistically significant.

# %% [markdown]
# * Any of the three models can be applied to identify the important features to predict the cyber attacks.

# %% [markdown]
# ## Correlations
#
# * To improve our understanding of the variables involved in cyber attack detection, we need to analyze the network data. Correlation diagrams can be helpful in visualizing how different variables are associated with each other and with cyber attacks. Additionally, random forest models can help identify the importance of different features in predicting the target variable (cyber attacks). We can compare the feature rankings from the random forest with the results of the correlation analysis to gain a better understanding of the key features to focus on for effective cyber attack detection.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Select only numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Set the figure size
plt.figure(figsize=(12, 10))

# Create the correlation matrix
corr_matrix = numeric_df.corr()

# Create a triangular mask to hide the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Create the heatmap
sns.heatmap(corr_matrix, vmin=-1, vmax=1, cmap='BrBG', mask=mask)

# Show the plot
plt.show()

# %% [markdown]
# ### Correlation of variables with cyber attack (label)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'label' is numeric or exclude it from correlation computation
numeric_df = df.select_dtypes(include=['float64', 'int64'])
feature_label_corr = numeric_df.corr()['label'].dropna().drop('label', errors='ignore')

# Sort correlations in descending order
feature_label_corr_sorted = feature_label_corr.sort_values(ascending=False)

# Plot horizontal bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x=feature_label_corr_sorted.values, y=feature_label_corr_sorted.index, palette='BrBG')
plt.xlabel('Correlation with Label')
plt.ylabel('Features')
plt.title('Features Correlating with the Label')
plt.show()

# %% [markdown]
# **Positively Correlated Variables:**
# 1. **sttl (Source to Destination Time to Live Value):** This variable indicates the time-to-live value in IP packets from the source to the destination. A positive correlation suggests that as the time-to-live value increases, the likelihood of cyber attacks also increases. This could imply that longer time-to-live values are associated with certain types of attacks.
#
# 2. **ct_state_ttl and state:** These features relate to the various states of TCP connections. The correlation suggests that certain states of TCP connections, as represented by these features, are associated with a higher likelihood of cyber attacks. For example, specific state transitions or connection durations may indicate reconnaissance activities or exploit attempts.
#
# 3. **ct_dst_sport_ltm (Count of Connections from the Same Source IP to the Same Destination Port in a Short Time Period):** This feature counts the number of connections from the same source IP address to the same destination port within a short time period. A positive correlation suggests that a higher count of such connections is associated with a higher likelihood of cyber attacks. This could indicate repeated access attempts or suspicious behavior.
#
# 4. **rate:** The "rate" feature likely represents various types of traffic rates or frequencies in the network data. A positive correlation suggests that higher traffic rates or frequencies are associated with a higher likelihood of cyber attacks. This could indicate increased network activity, which may be indicative of attack behavior.
#
# **Negatively Correlated Variables:**
# 1. **swin (Total Size of the TCP Window):** This variable represents the total size of the TCP window, which is a flow control mechanism in TCP connections. A negative correlation suggests that lower TCP window sizes are associated with a higher likelihood of cyber attacks. This could indicate that certain types of attacks are more prevalent when TCP window sizes are smaller.
#
# 2. **dload:** The "dload" feature likely represents the download data size. A negative correlation suggests that lower download data sizes are associated with a higher likelihood of cyber attacks. This could indicate that certain attack activities lead to decreased download data sizes or less data transfer overall.

# %% [markdown]
# ## Feature Ranking from Random Forest

# %%
import pandas as pd

# Create DataFrame with feature names and importances
feature_imp = pd.DataFrame({'Name': X.columns, 'Importance': rf.feature_importances_})

# Sort DataFrame by importance in descending order
feature_imp_sorted = feature_imp.sort_values('Importance', ascending=False)

# Select top 10 features
top_10_features = feature_imp_sorted.head(10)

# Apply background gradient style
styled_top_10_features = top_10_features.style.background_gradient()

styled_top_10_features
# Out:
# <style type="text/css">
# #T_e8960_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e8960_row1_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_e8960_row2_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e8960_row3_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_e8960_row4_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e8960_row5_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_e8960_row6_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e8960_row7_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e8960_row8_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_e8960_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_e8960">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8960_level0_col0" class="col_heading level0 col0" >Name</th>
# ...

# %%
import matplotlib.pyplot as plt

# Create a Series with feature importances and corresponding index
feat_importances = pd.Series(rf.feature_importances_, index=X.columns)

# Select the top 20 most important features and plot them
top_20_features = feat_importances.nlargest(20)
top_20_features.plot(kind='barh', color=['g', 'b'] * 10)  # Alternating colors for bars
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 20 Most Important Features')
plt.show()

# %% [markdown]
# ### Let's select only the top 10 features and find their associations with the type of cyber attack.

# %%
# Sort the feature_imp DataFrame by importance in descending order
feature_imp_sorted = feature_imp.sort_values(by='Importance', ascending=False)

# Select the top 10 features
top_10 = feature_imp_sorted['Name'].head(10).tolist()
top_10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Sort the feature_imp DataFrame by importance in descending order
# ----> 2 feature_imp_sorted = feature_imp.sort_values(by='Importance', ascending=False)
#       4 # Select the top 10 features
#       5 top_10 = feature_imp_sorted['Name'].head(10).tolist()
#
# NameError: name 'feature_imp' is not defined

# %%
from sklearn.model_selection import cross_val_score

# Define the features and target variable
X = df[top10]
y = df['label']

# Initialize the random forest classifier
rf_top10 = RandomForestClassifier(random_state=11)

# Perform cross-validation to evaluate model performance
cv_scores = cross_val_score(rf_top10, X, y, cv=5, scoring='accuracy')

print("Cross-Validation Accuracy Scores:", cv_scores)
print("Mean Accuracy:", cv_scores.mean())

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11)

# Fit the model on the training data
rf_top10.fit(X_train, y_train)

# Predict the target variable on the testing data
y_pred = rf_top10.predict(X_test)

# Evaluate model performance
acc = accuracy_score(y_test, y_pred)
print("Accuracy: ", acc)
# Out:
# Cross-Validation Accuracy Scores: [0.95936742 0.81237994 0.92372174 0.96375209 0.88671557]
# Mean Accuracy: 0.9091873502188899
# Accuracy:  0.9334299241934232

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import numpy as np

# Select top 10 features
top_10_features = feature_imp_sorted.head(10)['Name'].tolist()

# Get unique attack category names
# Convert Categorical object to list
attack_names = df['attack_cat'].unique().tolist()


# Filter dataset to include only the top 10 features
X_top = df[top_10_features]
y_top = pd.factorize(df['attack_cat'])[0]

# Train-test split
X_train_top, X_test_top, y_train_top, y_test_top = train_test_split(X_top, y_top, test_size=0.3, random_state=11)

# Initialize and train DecisionTreeClassifier
clf_top10 = DecisionTreeClassifier(max_depth=6)
clf_top10.fit(X_train_top, y_train_top)

# Visualize the decision tree
viz_model = dtreeviz.model(clf_top10, 
                                     X_train=X_train_top, 
                                     y_train=y_train_top,
                                     feature_names=top_10_features,
                                     target_name='attack_cat', 
                                     class_names=attack_names)

viz_model.view(fancy=False, scale=1)

# %% [markdown]
# ## Random Forest With Attack Category As the Prediction Labels

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Select top 10 features
top_10_features = feature_imp_sorted.head(10)['Name'].tolist()

# Filter dataset to include only the top 10 features
X = df.loc[:, df.columns.isin(top_10_features)]
y = df['attack_cat'].values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11)

# Initialize and train RandomForestClassifier
rf = RandomForestClassifier(random_state=11, min_samples_leaf=1, min_samples_split=5, n_estimators=100)
rf.fit(X_train, y_train)

# Predict
y_pred = rf.predict(X_test)

# Compute accuracy
acc = accuracy_score(y_test, y_pred)
print("Accuracy: ", acc)

# Visualize confusion matrix
cross = pd.crosstab(y_test, y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cross, annot=True, fmt='d', cmap="YlGnBu")
plt.show()
# Out:
# Accuracy:  0.8243253732115599

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                 precision    recall  f1-score   support
#
#       Analysis       0.76      0.09      0.16       768
#       Backdoor       0.52      0.07      0.12       658
#            DoS       0.38      0.16      0.23      4909
#       Exploits       0.63      0.87      0.73     13403
#        Fuzzers       0.66      0.60      0.63      7283
#        Generic       1.00      0.98      0.99     17790
#         Normal       0.91      0.93      0.92     27814
# Reconnaissance       0.91      0.75      0.82      4198
#      Shellcode       0.63      0.59      0.61       418
#          Worms       0.69      0.39      0.50        61
#
#       accuracy                           0.82     77302
#      macro avg       0.71      0.54      0.57     77302
#   weighted avg       0.82      0.82      0.81     77302

# %% [markdown]
# * Generic, Normal, and Exploits attacks have high recalls.

# %%
from sklearn.metrics import multilabel_confusion_matrix

# Calculate multilabel confusion matrix
mcm = multilabel_confusion_matrix(y_test, y_pred)

# Get unique attack categories
attack_categories = df['attack_cat'].unique()

# Plot confusion matrices for each attack category
for cm, category in zip(mcm, attack_categories):
    plt.figure(figsize=(5, 3))
    sns.heatmap(cm, annot=True, fmt='d', cmap="PiYG")
    plt.title(category)
    plt.show()

# %% [markdown]
# * Fuzzers, Reconaissance, and Analysis has true negatives and false negatives.

# %% [markdown]
# ## Conclusion
#
# * The Random Forest Model is best for cyber attack detection.
# * Decision Tree Model was used to identify the rules of cyber attack detection.
# * From this analysis, most important features were identified which has major role in cyber attack detection.
# * Random Forest Model is performing well in accuracy with both dependent feature, label and attack category.
